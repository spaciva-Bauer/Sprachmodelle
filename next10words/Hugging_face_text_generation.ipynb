# %% [raw]
# pip install transformers

# %% [raw]
# pip install jinja2==3.1.0

# %%
from transformers import pipeline

# %%
pipe = pipeline("text-generation", model="Qwen/Qwen3-0.6B",max_new_tokens=1, max_length=1, num_return_sequences=5)
# Out:
# Device set to use cpu

# %%
prompt = "Die Bayerische Staatskanzlei ist eine"
antwortprompt = pipe(prompt)
antwortprompt
# Out:
# [{'generated_text': 'Die Bayerische Staatskanzlei ist eine institution'},
#  {'generated_text': 'Die Bayerische Staatskanzlei ist eine der'},
#  {'generated_text': 'Die Bayerische Staatskanzlei ist eine polit'},
#  {'generated_text': 'Die Bayerische Staatskanzlei ist eine institution'},
#  {'generated_text': 'Die Bayerische Staatskanzlei ist eine der'}]
