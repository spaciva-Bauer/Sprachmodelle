# %%
from transformers import pipeline

# %%
unmasker = pipeline("fill-mask", model="FacebookAI/xlm-roberta-large")
unmasker("Die Bayerische Staatskanzlei ist eine <mask>", top_k=10)
# Out:
# Some weights of the model checkpoint at FacebookAI/xlm-roberta-large were not used when initializing XLMRobertaForMaskedLM: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing XLMRobertaForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu
# [{'score': 0.21647007763385773,
#   'token': 2,
#   'token_str': '</s>',
#   'sequence': 'Die Bayerische Staatskanzlei ist eine'},
#  {'score': 0.2048325091600418,
#   'token': 105251,
#   'token_str': 'Institution',
#   'sequence': 'Die Bayerische Staatskanzlei ist eine Institution'},
#  {'score': 0.088201604783535,
#   'token': 135778,
#   'token_str': 'Stiftung',
#   'sequence': 'Die Bayerische Staatskanzlei ist eine Stiftung'},
#  {'score': 0.06036226451396942,
#   'token': 153,
#   'token_str': '...',
#   'sequence': 'Die Bayerische Staatskanzlei ist eine ...'},
#  {'score': 0.05145774781703949,
#   'token': 27,
#   'token_str': '...',
#   'sequence': 'Die Bayerische Staatskanzlei ist eine...'},
#  {'score': 0.041871413588523865,
#   'token': 12,
#   'token_str': ':',
#   'sequence': 'Die Bayerische Staatskanzlei ist eine:'},
#  {'score': 0.03873078525066376,
#   'token': 152411,
#   'token_str': 'Berliner',
#   'sequence': 'Die Bayerische Staatskanzlei ist eine Berliner'},
#  {'score': 0.02918316051363945,
#   'token': 24641,
#   'token_str': 'Familie',
#   'sequence': 'Die Bayerische Staatskanzlei ist eine Familie'},
#  {'score': 0.02170073799788952,
#   'token': 55448,
#   'token_str': 'Organisation',
#   'sequence': 'Die Bayerische Staatskanzlei ist eine Organisation'},
#  {'score': 0.012952814809978008,
#   'token': 45227,
#   'token_str': 'GmbH',
#   'sequence': 'Die Bayerische Staatskanzlei ist eine GmbH'}]
